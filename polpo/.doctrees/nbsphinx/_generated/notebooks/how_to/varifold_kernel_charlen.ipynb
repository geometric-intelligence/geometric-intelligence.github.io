# %% [markdown]
# ## How to select the varifold kernel using characteristic lengths?
#
# Before, we presented a [decimated-based kernel tuning approach](./varifold_kernel_tuning.ipynb) that suffers from dependency on the characteristic length of the mesh.
#
# Here we present a more robust approach.

# %%
import numpy as np

import polpo.preprocessing.dict as ppdict
from polpo.mesh.surface import PvSurface
from polpo.mesh.varifold.tuning import SigmaBisecSearch, SigmaFromLengths
from polpo.preprocessing.load.pregnancy.jacobs import MeshLoader
# Out:
# [KeOps] Warning : CUDA was detected, but driver API could not be initialized. Switching to CPU only.

# %%
session_subset = np.random.choice(np.arange(1, 27))

mesh_loader = (
    MeshLoader(
        subject_subset=["01"],
        struct_subset=["L_Hipp"],
        session_subset=[session_subset],
        derivative="enigma",
        as_mesh=True,
    )
    + ppdict.ExtractUniqueKey(nested=True)
    + PvSurface
)

mesh = mesh_loader()

session_subset
# Out:
# np.int64(13)

# %%
sigma_search = SigmaFromLengths(
    ratio_charlen_mesh=2.0,
    ratio_charlen=0.25,
)

# %%
sigma_search.fit([mesh, mesh])


sigma_search.sigma_
# Out:
# np.float64(5.483330425019285)

# %% [markdown]
# Quick comparison with [decimation-based approach](./varifold_kernel_tuning.ipynb).

# %%
ref_value = 0.1
grid_search = SigmaBisecSearch(
    ref_value=ref_value,
    decimator=True,
)

grid_search.fit([mesh])

grid_search.sigma_, grid_search.sdist_
# Out:
# (np.float64(3.2128889209097373), np.float64(0.09260475849441718))

# %% [markdown]
# ## Further reading
#
# * [Within dataset varifold distances](../examples/varifold_distance_dataset.ipynb)
#
# * [Pairwise distances between different parametrizations of the same shape](../examples/varifold_decimation_charlen.ipynb)
#
# * [How to automatically select the varifold kernel using a decimation-based approach?](./varifold_kernel_tuning.ipynb)
